# %%
# imports
import pandas as pd
import numpy as np

# %%
# read in data
df = pd.read_csv('video_games_sales.csv', sep=';')
df.sample(5)
# Out:
#                                    Name Platform Year_of_Release   Genre  \
# 16628                  Crossroad Crisis       PS            2000  Puzzle
# 15902                  Zombie Hunters 2      PS2            2006  Action
# 5638   Disney's Extreme Skate Adventure      PS2            2003  Sports
# 11968                     Homie Rollerz       DS            2008  Racing
# 1739              Mario vs. Donkey Kong      GBA            2004  Puzzle
#
#              Publisher NA_Sales EU_Sales JP_Sales Other_Sales Global_Sales  \
# 16628          Success     0,01        0        0           0         0,01
# 15902  Essential Games        0        0     0,02           0         0,02
# 5638        Activision     0,16     0,12        0        0,04         0,32
# 11968        Destineer     0,07        0        0        0,01         0,07
# 1739          Nintendo     0,68     0,25     0,21        0,02         1,17
#
# ...
